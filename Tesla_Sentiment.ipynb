# %% [markdown]
# #Web Scrapping

# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
#pd.set_option('display.max_rows', 5000)

# %%
r = requests.get('https://www.yelp.com/biz/tesla-san-francisco?osq=Tesla+Dealership')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n            window.OneTrust = window.OneTrust || {};\n            window.OneTrust.dataSubjectParams = window.OneTrust.dataSubjectParams || {};\n            window.OneTrust.dataSubjectParams.id = \'\';\n            window.OneTrust.dataSubjectParams.isAnonymous = true;\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/consent/5fbcd417-fbc1-4fcc-abad-f622f1bba72d/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><script async src="https://www.googletagmanager.com/gtag/js?id=G-K9Z2ZEVC8C&l=ga4DataLayer"></script><script>window.ga4DataLayer=window.ga4DataLayer||[];function ga4Tag(){ga4DataLayer.push(arguments);};ga4Tag("js",new Date());ga4Tag("config","G-K9Z2ZEVC8C",{send_page_view:false});</script><meta id="emotion-container"><style data-emotion="yelp-emotion-global xl0fej">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none;}table{border-collapse:collapse;border-spacing:0;}</style><style data-emotion="yelp-emotion-global zpdl00">.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none!important;}@media only screen and (max-width: 600px){.responsive:not(.responsive-biz) .responsive-small-display-inline-block{display:inline-block!important;}.responsive:not(.responsive-biz) .responsive-small-display-block{display:block!important;}.responsive:not(.responsive-biz) .responsive-small-display-inline{display ...

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
p = soup.findAll(class_ = "comment__09f24__D0cxf yelp-emotion-19a3fsb")

# %%
p
# Out:
# [<p class="comment__09f24__D0cxf yelp-emotion-19a3fsb"><span class="raw__09f24__T4Ezm" lang="en">Staff is very professional and courteous.  Once you get inside, it's beautiful and spacious.  The waiting room has free drinks, coffee and snacks.  Plenty of tables and couches to relax or get on your iPad:  <br/><br/>I would give them 5 stars, but I'm. It crazy about the location on Van Ness.</span></p>,
#  <p class="comment__09f24__D0cxf yelp-emotion-19a3fsb"><span class="raw__09f24__T4Ezm" lang="en">Came here to get warranty work done as my driver side headlight went bad.  Came in 30min early to my appointment in the morning and the service guys greeted me quickly and took me in early no issues.  They told me it would take roughly an hour to get the job done. The work ended up taking 55min exactly so pretty accurate estimate.  Got my car back with everything working and not a single scratch or dent from service guys.  A+ work thank you!</span></p>,
#  <p class="comment__09f24__D0cxf yelp-emotion-19a3fsb"><span class="raw__09f24__T4Ezm" lang="en
# %%
reviews[0]
# Out:
# "Staff is very professional and courteous.  Once you get inside, it's beautiful and spacious.  The waiting room has free drinks, coffee and snacks.  Plenty of tables and couches to relax or get on your iPad:  I would give them 5 stars, but I'm. It crazy about the location on Van Ness."

# %% [markdown]
# #Analysing The Data

# %%
df = pd.DataFrame(np.array(reviews), columns=["review"])

# %%
df.head()
# Out:
#                                               review
# 0  Staff is very professional and courteous.  Onc...
# 1  Came here to get warranty work done as my driv...
# 2  I was told I would get an IRS tax rebate, even...
# 3  I am giving one star for the young man Kenny. ...
# 4  Helena KElon Musk!Is climbing the highest moun...

# %%
len(df['review'])
# Out:
# 10

# %%
df['word count'] = df['review'].apply(lambda x: len(x.split()))

# %%
df.head()
# Out:
#                                               review  word count
# 0  Staff is very professional and courteous.  Onc...          51
# 1  Came here to get warranty work done as my driv...          84
# 2  I was told I would get an IRS tax rebate, even...          92
# 3  I am giving one star for the young man Kenny. ...          59
# 4  Helena KElon Musk!Is climbing the highest moun...         125

# %%
df['char count'] = df['review'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                               review  word count  char count
# 0  Staff is very professional and courteous.  Onc...          51         284
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 3  I am giving one star for the young man Kenny. ...          59         303
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745

# %%
def average_words(x):
  words = x.split()
  return sum(len(word) for word in words) / len(words)

# %%
df['average_word_length'] = df['review'].apply(lambda x: average_words(x))

# %%
df.head()
# Out:
#                                               review  word count  char count  \
# 0  Staff is very professional and courteous.  Onc...          51         284
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 3  I am giving one star for the young man Kenny. ...          59         303
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
#
#    average_word_length
# 0             4.509804
# 1             4.261905
# 2             4.250000
# 3             4.152542
# 4             4.960000

# %%
from nltk.corpus import stopwords

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = stopwords.words('english')

# %%
len(stop_words)
# Out:
# 179

# %%
df['stopword_count'] = df['review'].apply(lambda x: len([word for word in x.split() if word.lower() in stop_words]))

# %%
df['stopword_rate'] = df['stopword_count'] / df['word count']

# %%
df.head()
# Out:
#                                               review  word count  char count  \
# 0  Staff is very professional and courteous.  Onc...          51         284
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 3  I am giving one star for the young man Kenny. ...          59         303
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.509804              23       0.450980
# 1             4.261905              32       0.380952
# 2             4.250000              47       0.510870
# 3             4.152542              30       0.508475
# 4             4.960000              48       0.384000

# %%
df.sort_values(by='stopword_rate')
# Out:
#                                               review  word count  char count  \
# 1  Came here to get warranty work done as my driv...          84         445
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
# 6  Tesla comes with self drive as long as you hav...          42         219
# 0  Staff is very professional and courteous.  Onc...          51         284
# 8  In a nutshell: Tesla sucks! I leased one of th...         136         734
# 3  I am giving one star for the young man Kenny. ...          59         303
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 9  I waited for 25 mins and no one even acknowled...          59         278
# 5  I took my car to Tesla for a recall. First- th...          96         454
# 7  Wow! The best tesla service center I have ever...         109         531
#
#    average_word_length  stopword_count  stopword_rate
# 1             4.261905              32       0.380952
# 4             4.960000              48       0.384000
# 6             4.238095              18       0.428571
# 0             4.509804              23       0.450980
# 8             4.404412              65       0.477941
# 3             4.152542              30       0.508475
# 2             4.250000              47       0.510870
# 9             3.728814              31       0.525424
# 5             3.739583              51       0.531250
# 7             3.880734              58       0.532110

# %%
df.describe()
# Out:
#        word count  char count  average_word_length  stopword_count  \
# count   10.000000   10.000000            10.000000       10.000000
# mean    85.300000  447.700000             4.212589       40.300000
# std     32.152588  184.841103             0.374128       15.635075
# min     42.000000  219.000000             3.728814       18.000000
# 25%     59.000000  288.750000             3.948686       30.250000
# 50%     88.000000  449.500000             4.244048       39.500000
# 75%    105.750000  519.250000             4.368785       50.250000
# max    136.000000  745.000000             4.960000       65.000000
#
#        stopword_rate
# count      10.000000
# mean        0.473057
# std         0.058883
# min         0.380952
# 25%         0.434174
# 50%         0.493208
# 75%         0.521785
# max         0.532110

# %% [markdown]
# #Data Cleaning

# %%
df['review']
# Out:
# 0    Staff is very professional and courteous.  Onc...
# 1    Came here to get warranty work done as my driv...
# 2    I was told I would get an IRS tax rebate, even...
# 3    I am giving one star for the young man Kenny. ...
# 4    Helena KElon Musk!Is climbing the highest moun...
# 5    I took my car to Tesla for a recall. First- th...
# 6    Tesla comes with self drive as long as you hav...
# 7    Wow! The best tesla service center I have ever...
# 8    In a nutshell: Tesla sucks! I leased one of th...
# 9    I waited for 25 mins and no one even acknowled...
# Name: review, dtype: object

# %%
df['lowercase'] = df['review'].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
df['punctuation'] = df['lowercase'].str.replace('[^\w\s]', '')

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
df['stopwords'] = df['punctuation'].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))

# %%
df.head()
# Out:
#                                               review  word count  char count  \
# 0  Staff is very professional and courteous.  Onc...          51         284
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 3  I am giving one star for the young man Kenny. ...          59         303
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.509804              23       0.450980
# 1             4.261905              32       0.380952
# 2             4.250000              47       0.510870
# 3             4.152542              30       0.508475
# 4             4.960000              48       0.384000
#
#                                            lowercase  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                          punctuation  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                            stopwords
# 0  staff professional courteous. get inside, beau...
# 1  came get warranty work done driver side headli...
# 2  told would get irs tax rebate, even thought to...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...

# %%
pd.Series(" ".join(df['stopwords']).split()).value_counts()[:30]
# Out:
# tesla          11
# get             9
# one             7
# told            6
# even            5
# service         5
# work            4
# car             4
# take            4
# would           4
# call            3
# working         3
# appointment     3
# say             3
# back            3
# buy             2
# early           2
# issues.         2
# number          2
# took            2
# another         2
# salesman        2
# side            2
# best            2
# hands           2
# got             2
# need            2
# wheel.          2
# salesmen        2
# going           2
# Name: count, dtype: int64

# %%
other_stop_words = ['get', 'even', 'next', 'back', 'took','take','would','going']

# %%
len(other_stop_words)
# Out:
# 8

# %%
df['cleaned_review'] = df['stopwords'].apply(lambda x: " ".join(word for word in x.split() if word not in other_stop_words))

# %%
pd.Series(" ".join(df['cleaned_review']).split()).value_counts()[:30]
# Out:
# tesla          11
# one             7
# told            6
# service         5
# work            4
# car             4
# call            3
# appointment     3
# say             3
# working         3
# hands           2
# early           2
# number          2
# issues.         2
# got             2
# need            2
# wheel.          2
# side            2
# salesmen        2
# another         2
# salesman        2
# buy             2
# able            2
# check           2
# make            2
# man             2
# great           2
# insurance       2
# best            2
# person          2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                               review  word count  char count  \
# 0  Staff is very professional and courteous.  Onc...          51         284
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 3  I am giving one star for the young man Kenny. ...          59         303
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.509804              23       0.450980
# 1             4.261905              32       0.380952
# 2             4.250000              47       0.510870
# 3             4.152542              30       0.508475
# 4             4.960000              48       0.384000
#
#                                            lowercase  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                          punctuation  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                            stopwords  \
# 0  staff professional courteous. get inside, beau...
# 1  came get warranty work done driver side headli...
# 2  told would get irs tax rebate, even thought to...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...
#
#                                       cleaned_review
# 0  staff professional courteous. inside, beautifu...
# 1  came warranty work done driver side headlight ...
# 2  told irs tax rebate, thought told salesmen inc...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...

# %%
df['cleaned_review_word_count'] = df['cleaned_review'].apply(lambda x: len(x.split()))

# %%
df['clean_rate'] = df['cleaned_review_word_count'] / df['word count']

# %%
df.head()
# Out:
#                                               review  word count  char count  \
# 0  Staff is very professional and courteous.  Onc...          51         284
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 3  I am giving one star for the young man Kenny. ...          59         303
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.509804              23       0.450980
# 1             4.261905              32       0.380952
# 2             4.250000              47       0.510870
# 3             4.152542              30       0.508475
# 4             4.960000              48       0.384000
#
#                                            lowercase  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                          punctuation  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                            stopwords  \
# 0  staff professional courteous. get inside, beau...
# 1  came get warranty work done driver side headli...
# 2  told would get irs tax rebate, even thought to...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...
#
#                                       cleaned_review  \
# 0  staff professional courteous. inside, beautifu...
# 1  came warranty work done driver side headlight ...
# 2  told irs tax rebate, thought told salesmen inc...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...
#
#    cleaned_review_word_count  clean_rate
# 0                         25    0.490196
# 1                         46    0.547619
# 2                         40    0.434783
# 3                         29    0.491525
# 4                         74    0.592000

# %% [markdown]
# #Lemmatization

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.2)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
# !pip show textblob
# Out:
# Name: textblob
# Version: 0.17.1
# Summary: Simple, Pythonic text processing. Sentiment analysis, part-of-speech tagging, noun phrase parsing, and more.
# Home-page: https://github.com/sloria/TextBlob
# Author: Steven Loria
# Author-email: sloria1@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: nltk
# Required-by:

# %%
import textblob
dir(textblob)
# Out:
# ['Blobber',
#  'PACKAGE_DIR',
#  'Sentence',
#  'TextBlob',
#  'Word',
#  'WordList',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_text',
#  'base',
#  'blob',
#  'compat',
#  'decorators',
#  'en',
#  'exceptions',
#  'inflect',
#  'mixins',
#  'np_extractors',
#  'os',
#  'parsers',
#  'sentiments',
#  'taggers',
#  'tokenizers',
#  'translate',
#  'utils']

# %%
# !pip install --upgrade textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.3/626.3 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.8 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.8->textblob) (4.66.2)
# Installing collected packages: textblob
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.17.1
#     Uninstalling textblob-0.17.1:
#       Successfully uninstalled textblob-0.17.1
# Successfully installed textblob-0.18.0.post0

# %%
from textblob import Word

# %%
df['lemmatized'] = df['cleaned_review'].apply(lambda x: " ".join(Word(word).lemmatize() for word in x.split()))

# %%
df.head()
# Out:
#                                               review  word count  char count  \
# 0  Staff is very professional and courteous.  Onc...          51         284
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 3  I am giving one star for the young man Kenny. ...          59         303
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
#
#    average_word_length  stopword_count  stopword_rate  \
# 0             4.509804              23       0.450980
# 1             4.261905              32       0.380952
# 2             4.250000              47       0.510870
# 3             4.152542              30       0.508475
# 4             4.960000              48       0.384000
#
#                                            lowercase  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                          punctuation  \
# 0  staff is very professional and courteous. once...
# 1  came here to get warranty work done as my driv...
# 2  i was told i would get an irs tax rebate, even...
# 3  i am giving one star for the young man kenny. ...
# 4  helena kelon musk!is climbing the highest moun...
#
#                                            stopwords  \
# 0  staff professional courteous. get inside, beau...
# 1  came get warranty work done driver side headli...
# 2  told would get irs tax rebate, even thought to...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...
#
#                                       cleaned_review  \
# 0  staff professional courteous. inside, beautifu...
# 1  came warranty work done driver side headlight ...
# 2  told irs tax rebate, thought told salesmen inc...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...
#
#    cleaned_review_word_count  clean_rate  \
# 0                         25    0.490196
# 1                         46    0.547619
# 2                         40    0.434783
# 3                         29    0.491525
# 4                         74    0.592000
#
#                                           lemmatized
# 0  staff professional courteous. inside, beautifu...
# 1  came warranty work done driver side headlight ...
# 2  told irs tax rebate, thought told salesman inc...
# 3  giving one star young man kenny. great persona...
# 4  helena kelon musk!is climbing highest mount wo...

# %% [markdown]
# # Sentiment Analysis

# %%
from textblob import TextBlob

# %%
#Based on positive ir negatice review
df['polarity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
#based on facts
df['subjectivity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[1])

# %%
df.drop(['lowercase','punctuation','stopwords','cleaned_review','lemmatized'],axis = 1, inplace=True)

# %%
df.sort_values(by = 'polarity')
# Out:
#                                               review  word count  char count  \
# 8  In a nutshell: Tesla sucks! I leased one of th...         136         734
# 5  I took my car to Tesla for a recall. First- th...          96         454
# 9  I waited for 25 mins and no one even acknowled...          59         278
# 1  Came here to get warranty work done as my driv...          84         445
# 2  I was told I would get an IRS tax rebate, even...          92         484
# 7  Wow! The best tesla service center I have ever...         109         531
# 6  Tesla comes with self drive as long as you hav...          42         219
# 0  Staff is very professional and courteous.  Onc...          51         284
# 4  Helena KElon Musk!Is climbing the highest moun...         125         745
# 3  I am giving one star for the young man Kenny. ...          59         303
#
#    average_word_length  stopword_count  stopword_rate  \
# 8             4.404412              65       0.477941
# 5             3.739583              51       0.531250
# 9             3.728814              31       0.525424
# 1             4.261905              32       0.380952
# 2             4.250000              47       0.510870
# 7             3.880734              58       0.532110
# 6             4.238095              18       0.428571
# 0             4.509804              23       0.450980
# 4             4.960000              48       0.384000
# 3             4.152542              30       0.508475
#
#    cleaned_review_word_count  clean_rate  polarity  subjectivity
# 8                         68    0.500000 -0.202500      0.545833
# 5                         42    0.437500 -0.147500      0.556667
# 9                         26    0.440678 -0.081818      0.450000
# 1                         46    0.547619 -0.005612      0.502041
# 2                         40    0.434783  0.100000      0.475000
# 7                         47    0.431193  0.203958      0.379167
# 6                         22    0.523810  0.225000      0.700000
# 0                         25    0.490196  0.270000      0.760000
# 4                         74    0.592000  0.352778      0.674074
# 3                         29    0.491525  0.500000      0.412500
